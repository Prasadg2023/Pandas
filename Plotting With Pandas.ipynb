# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Plotting With Pandas

# %%
df=pd.read_csv("Data/Iris (1).csv")
df
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Line plot

# %%
df["SepalLengthCm"].plot(kind="line",figsize=(10,5),c="r",ylabel="SepalLengthCm")
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
df["SepalLengthCm"].plot.line()
# Out:
# <Axes: >

# %% [markdown]
# # Bar plot

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df["Species"].value_counts().plot(kind = "bar", color = "r")
# Out:
# <Axes: xlabel='Species'>

# %%
df["Species"].value_counts().plot(kind = "barh", color = "r")
# Out:
# <Axes: ylabel='Species'>

# %% [markdown]
# # Histogram plot

# %%
df["SepalLengthCm"].plot(kind="hist", bins=50 , edgecolor = "k")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot

# %%
df["SepalLengthCm"].plot(kind="box")
# Out:
# <Axes: >

# %%
df.iloc[:,1:].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# # KDE (Kernel Density Estimation) plot

# %%
df["SepalLengthCm"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Area plot

# %%
df.loc[:,["SepalLengthCm","SepalWidthCm"]].plot(kind = "area")
# Out:
# <Axes: >

# %% [markdown]
# # Scatter plots

# %%
df.plot(x = "SepalLengthCm",y = "SepalWidthCm",kind = "scatter")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# # Pie chart

# %%
df["Species"].value_counts().plot(kind = "pie", autopct = "%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Hexbin plot

# %%
df.plot(kind = "hexbin",x = "SepalLengthCm",y = "SepalWidthCm", cmap = "coolwarm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>
