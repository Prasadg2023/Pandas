# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Data Analysis\\EDA\\Pandas\\Lessons'

# %%
df = pd.read_csv("Data\std_data1.csv")
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
pd.read_csv(r"Data\std_data1.csv",index_col = "SNAME")
# Out:
#        SCLASS   ENGLISH  COMPUTER  SCIENCE
# SNAME
# A           10       67        66       66
# B           12       87        56       65
# C           11       66        89       63
# D           10       56        88       66
# E           10       89        90       56
# F            9       88        85       89
# G           12       90        83       88
# H           11       79        88       90

# %%
df_index = df.set_index("SNAME")
df_index
# Out:
#        SCLASS   ENGLISH  COMPUTER  SCIENCE
# SNAME
# A           10       67        66       66
# B           12       87        56       65
# C           11       66        89       63
# D           10       56        88       66
# E           10       89        90       56
# F            9       88        85       89
# G           12       90        83       88
# H           11       79        88       90

# %%
df_index1 = df.set_index("SNAME",drop = False)
df_index1
# Out:
#       SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# SNAME
# A         A       10       67        66       66
# B         B       12       87        56       65
# C         C       11       66        89       63
# D         D       10       56        88       66
# E         E       10       89        90       56
# F         F        9       88        85       89
# G         G       12       90        83       88
# H         H       11       79        88       90

# %%
df_index1.reset_index(drop = True)
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %% [markdown]
# # Sorting DataFrame

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.iloc[[2,5,3,7,1],:]
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 2     C       11       66        89       63
# 5     F        9       88        85       89
# 3     D       10       56        88       66
# 7     H       11       79        88       90
# 1     B       12       87        56       65

# %%
df.iloc[[2,5,3,7,1],:].sort_index() #sorting by index
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 5     F        9       88        85       89
# 7     H       11       79        88       90

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.sort_index(ascending = False) #in descending order by index
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 7     H       11       79        88       90
# 6     G       12       90        83       88
# 5     F        9       88        85       89
# 4     E       10       89        90       56
# 3     D       10       56        88       66
# 2     C       11       66        89       63
# 1     B       12       87        56       65
# 0     A       10       67        66       66

# %% [markdown]
# # Sorting DataFrame by values

# %%
df.sort_values(by = "ENGLISH")
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 3     D       10       56        88       66
# 2     C       11       66        89       63
# 0     A       10       67        66       66
# 7     H       11       79        88       90
# 1     B       12       87        56       65
# 5     F        9       88        85       89
# 4     E       10       89        90       56
# 6     G       12       90        83       88

# %%
df.sort_values(by = "ENGLISH", ascending = False) #inndescendong order
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 6     G       12       90        83       88
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 1     B       12       87        56       65
# 7     H       11       79        88       90
# 0     A       10       67        66       66
# 2     C       11       66        89       63
# 3     D       10       56        88       66

# %%
df.sort_values(by = ["ENGLISH","SNAME","COMPUTER","SCIENCE"])
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 3     D       10       56        88       66
# 2     C       11       66        89       63
# 0     A       10       67        66       66
# 7     H       11       79        88       90
# 1     B       12       87        56       65
# 5     F        9       88        85       89
# 4     E       10       89        90       56
# 6     G       12       90        83       88

# %%
df.sort_values(by = ["ENGLISH","SNAME","COMPUTER","SCIENCE"],ascending = False)
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 6     G       12       90        83       88
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 1     B       12       87        56       65
# 7     H       11       79        88       90
# 0     A       10       67        66       66
# 2     C       11       66        89       63
# 3     D       10       56        88       66
